# %% [markdown]
# ![Q1.jpg](attachment:4aa7320a-653b-4253-9bd4-cba0702e6659.jpg)

# %%
#Ans 1:- GET: It is used to send or receive data fromt he the client through the url of the server. In this ways of getting data the data is directly passed into the url.
#        POST: It is the way of sending or receiving data by the body not with the url itself due to which the data is not catched by the server.

# %% [markdown]
# ![Q2.jpg](attachment:bc44467d-cff9-45ef-9309-92f2a3ba4fe4.jpg)

# %%
#Ans 2:- Request is a object of the Flask which is used to stores all the data received from client to the server.
#        The request object basically process the incoming data from the url
#        we can access that data through the request methods like GET and POST.

# %% [markdown]
# ![Q3.jpg](attachment:fd62fd25-1af1-4202-8a01-f51b687dfa8d.jpg)

# %%
#Ans: The redirect() method is a method used to handle the unwanted situation or error created due to certain problems.
#    these problems can be login error, page not found etc. If certain things happens we want a user to redirect to a page again.
#    for example: we created a login page where the validation is done and then if there is successful login then the user is allowed
#    visit the next page otherwise the user is directed to the login page for that purpose redirect() is used

# %% [markdown]
# ![Q4.jpg](attachment:62bcbd47-4d10-42e4-9c0e-84953059cdab.jpg)

# %%
#Ans4: templates are the files with the static or dynamic data which is rendered with the data client data to show the desired result.
#    like in case of a website a html file is a templete for the flask.
#    render_template() is a function used to render the template file with the client data and generate output.

# %% [markdown]
# ![Q5.jpg](attachment:1b62b0d7-f6d0-4775-96a9-88b652278aeb.jpg)

# %% [markdown]
# ![ans5.jpg](attachment:b053487f-6a0a-4d3f-8e62-19f4ad46c2ca.jpg)
